# %% [markdown]
# ## List

# %%
# creation

numbers = [10, 20, 30, 40, 50]
fruits = ['apple', 'banana', 'cherry']
mixed_list = [7, 3.14, 'abc', True, None]

# %%
type(mixed_list)
# Out:
# list

# %%
# access

numbers[2]
# Out:
# 30

# %%
fruits[1]
# Out:
# 'banana'

# %%
# traversal

for fruit in fruits:
    print(fruit, end=" ")
# Out:
# apple banana cherry

# %%
# insertion

# append method

numbers
# Out:
# [10, 20, 30, 40, 50]

# %%
numbers.append(60)

# %%
numbers
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
# insert method

numbers.insert(3, 35) # at inder 3 we need 35

# %%
numbers
# Out:
# [10, 20, 30, 35, 40, 50, 60]

# %%
# merging

#extend method

fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
more_fruits = ['mango', 'lemon']

# %%
fruits.extend(more_fruits)

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'lemon']

# %%
some_more_fruits = ('watermelon', 'kiwi')

# %%
fruits.extend(some_more_fruits)

# %%
fruits
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'lemon', 'watermelon', 'kiwi']

# %%
# concatenation

li1 = [1, 2, 3]
li2 = [4, 5]

li1 + li2
# Out:
# [1, 2, 3, 4, 5]

# %%
# deletion 

# remove

li = [3, 4, 6, 4, 1, 6, 2]
print(li)

li.remove(6)
print(li)
# Out:
# [3, 4, 6, 4, 1, 6, 2]
# [3, 4, 4, 1, 6, 2]

# %%
# pop([i])

numbers
# Out:
# [10, 20, 30, 40, 50]

# %%
numbers.pop()
# Out:
# 50

# %%
numbers
# Out:
# [10, 20, 30, 40]

# %%
numbers.pop(2)
# Out:
# 30

# %%
numbers
# Out:
# [10, 20, 40]

# %%
# del keyword

del numbers[2]

# %%
numbers
# Out:
# [10, 20]

# %%
# clear

li
# Out:
# [3, 4, 4, 1, 6, 2]

# %%
li.clear()

# %%
li
# Out:
# []

# %%
type(li)
# Out:
# list

# %%
# updation

mixed_list
# Out:
# [7, 3.14, 'abc', True, None]

# %%
mixed_list[1] = 6.626

# %%
mixed_list
# Out:
# [7, 6.626, 'abc', True, None]

# %%
# count

li = [2, 3, 4, 2, 2, 5, 3]
li
# Out:
# [2, 3, 4, 2, 2, 5, 3]

# %%
li.count(2)
# Out:
# 3

# %%
# sorting

li
# Out:
# [2, 3, 4, 2, 2, 5, 3]

# %%
li.sort()

# %%
li
# Out:
# [2, 2, 2, 3, 3, 4, 5]

# %%
li1 = [2, 5, 3, 1, -4, 5]
sorted(li1)
# Out:
# [-4, 1, 2, 3, 5, 5]

# %%
#reverse

li1 = [3, 4, 1, 2, -5, 7, 4]
li1
# Out:
# [3, 4, 1, 2, -5, 7, 4]

# %%
li1.reverse()

# %%
li1
# Out:
# [4, 7, -5, 2, 1, 4, 3]

# %%
# copy

li1
# Out:
# [4, 7, -5, 2, 1, 4, 3]

# %%
li2 = li1.copy()
li2
# Out:
# [4, 7, -5, 2, 1, 4, 3]

# %%
li1.remove(4)
li1
# Out:
# [7, -5, 2, 1, 3]

# %%
li2
# Out:
# [4, 7, -5, 2, 1, 4, 3]

# %%
#split

li2
# Out:
# [4, 7, -5, 2, 1, 4, 3]

# %%
li2[:2]
# Out:
# [4, 7]

# %%
li2[1:]
# Out:
# [7, -5, 2, 1, 4, 3]
